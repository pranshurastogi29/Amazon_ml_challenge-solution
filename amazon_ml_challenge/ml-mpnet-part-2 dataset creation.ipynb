# %%
# !pip install -U sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 85 kB 1.6 MB/s
# ...
# done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126709 sha256=83e4e8c3d9bcd6deb45ee1296815c9bb479d005ac2cc0b90e5a7335b228f1db2
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built sentence-transformers
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import numpy as np
import pandas as pd
import torch
import gc
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv('../input/amazon-clean-dataset2/data.csv')
print('dataset_read')
model = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')
embeddings = model.encode(df['All'].values[500000:1000000], show_progress_bar=True)
del model , df
# Out:
# dataset_read
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.75k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/402 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/15625 [00:00<?, ?it/s]

# %%
np.save('data_embeddings2.npy',embeddings)
